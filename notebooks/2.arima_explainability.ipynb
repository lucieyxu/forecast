# %% [markdown]
# # ARIMA models explainability
#
# This notebook focuses on one ARIMA_PLUS_XREG model trained on one fold. It describes coefficients, training information and explanations for forecasts

# %%
from google.cloud import bigquery

# %%
PROJECT_ID = "luciexu"
BQ_DATASET = "citibike"
model_id = "citibike-arima-fold-3-2025-11-04-09-44-52"

BQ_TABLE = "citibike_trips_prepped-fold-3-2025-11-04-09-44-52"
SERIES_COLUMN = "time_serie_id"
TIME_COLUMN = "monday_of_week"
TARGET_COLUMN = "qty"
COVARIATE_COLUMNS = [
    "start_station_id",
    "start_station_latitude",
    "start_station_longitude",
    "end_station_id",
    "end_station_latitude",
    "end_station_longitude",
    "percentage_rain"
]
FORECAST_HORIZON_LENGTH = 10

bq = bigquery.Client(project = PROJECT_ID)

# %% [markdown]
# ## Model information

# %%
query = f"""
    SELECT *
    FROM ML.ARIMA_COEFFICIENTS(MODEL `{PROJECT_ID}.{BQ_DATASET}.{model_id}`)
"""
coefficients = bq.query(query).to_dataframe()
coefficients
# Out:
# /usr/local/lib/python3.12/dist-packages/google/cloud/bigquery/table.py:1957: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#                    time_serie_id ar_coefficients ma_coefficients  \
# 0          10avew28st_10avew28st              []              []
# 1          10avew28st_10avew28st              []              []
# 2          10avew28st_10avew28st              []              []
# 3          10avew28st_10avew28st              []              []
# 4          10avew28st_10avew28st              []              []
# ...                          ...             ...             ...
# 1793016  yorkstjayst_yorkstjayst              []              []
# 1793017  yorkstjayst_yorkstjayst              []              []
# 1793018  yorkstjayst_yorkstjayst              []              []
# 1793019  yorkstjayst_yorkstjayst              []              []
# 1793020  yorkstjayst_yorkstjayst              []              []
#
#          intercept_or_drift          processed_input    weight  \
# 0                       NaN         start_station_id  0.000000
# 1                       NaN   start_station_latitude -0.020241
# 2                       NaN  start_station_longitude  0.000000
# 3                       NaN           end_station_id  0.000935
# 4                       NaN     end_station_latitude  0.000000
# ...                     ...                      ...       ...
# 1793016                 NaN           end_station_id  0.005979
# 1793017                 NaN     end_station_latitude -0.020157
# 1793018                 NaN    end_station_longitude  0.000000
# 1793019                 NaN          percentage_rain -0.761810
# 1793020                 NaN            __INTERCEPT__  5.673858
#
#         category_weights
# 0                     []
# 1                     []
# 2                     []
# 3                     []
# 4                     []
# ...                  ...
# 1793016               []
# 1793017               []
# 1793018               []
# 1793019               []
# 1793020               []
#
# [1793021 rows x 7 columns]

# %%
query = f"""
    SELECT *
    FROM ML.FEATURE_INFO(MODEL `{PROJECT_ID}.{BQ_DATASET}.{model_id}`)
"""
featureInfo = bq.query(query).to_dataframe()
featureInfo.head()
# Out:
# /usr/local/lib/python3.12/dist-packages/google/cloud/bigquery/table.py:1957: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#                      input        min          max        mean      median  \
# 0                      qty   1.000000   838.000000    4.038904    2.000000
# 1            time_serie_id        NaN          NaN         NaN         NaN
# 2         start_station_id  72.000000  3266.000000  633.292144  412.000000
# 3   start_station_latitude  40.646678    40.787209   40.733041   40.734011
# 4  start_station_longitude -74.025450   -73.928504  -73.988276  -73.989129
#
#        stddev  category_count  null_count  dimension
# 0    5.660052            <NA>           0       <NA>
# 1         NaN          203674           0       <NA>
# 2  768.873268            <NA>           0       <NA>
# 3    0.022000            <NA>           0       <NA>
# 4    0.014769            <NA>           0       <NA>

# %%
query = f"""
    SELECT *
    FROM ML.TRAINING_INFO(MODEL `{PROJECT_ID}.{BQ_DATASET}.{model_id}`)
"""
trainingInfo = bq.query(query).to_dataframe()
trainingInfo.head()
# Out:
# /usr/local/lib/python3.12/dist-packages/google/cloud/bigquery/table.py:1957: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#    training_run  iteration  duration_ms
# 0             0          0        10570

# %% [markdown]
# ## Explanability

# %%
query = f"""
    SELECT *
    FROM ML.HOLIDAY_INFO(
        MODEL `{PROJECT_ID}.{BQ_DATASET}.{model_id}`)
"""
holiday_info = bq.query(query).to_dataframe()
holiday_info
# Out:
# /usr/local/lib/python3.12/dist-packages/google/cloud/bigquery/table.py:1957: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#       region            holiday_name primary_date  preholiday_days  \
# 0     GLOBAL  AllSaintsDay-Halloween   2000-10-31                1
# 1     GLOBAL  AllSaintsDay-Halloween   2001-10-31                1
# 2     GLOBAL  AllSaintsDay-Halloween   2002-10-31                1
# 3     GLOBAL  AllSaintsDay-Halloween   2003-10-31                1
# 4     GLOBAL  AllSaintsDay-Halloween   2004-10-31                1
# ...      ...                     ...          ...              ...
# 1901      US              VeteranDay   2026-11-11                1
# 1902      US              VeteranDay   2027-11-11                1
# 1903      US              VeteranDay   2028-11-11                1
# 1904      US              VeteranDay   2029-11-11                1
# 1905      US              VeteranDay   2030-11-11                1
#
#       postholiday_days
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1
# ...                ...
# 1901                 1
# 1902                 1
# 1903                 1
# 1904                 1
# 1905                 1
#
# [1906 rows x 5 columns]

# %%
chosen_id = "1avee30st_stmarkspl1ave"
query = f"""
    SELECT *, 
        EXTRACT(DATE FROM time_series_timestamp) AS {TIME_COLUMN}
    FROM ML.EXPLAIN_FORECAST(
        MODEL `{PROJECT_ID}.{BQ_DATASET}.{model_id}`,
        STRUCT({FORECAST_HORIZON_LENGTH} AS horizon, 0.95 AS confidence_level),
        (
            SELECT {SERIES_COLUMN}, {TIME_COLUMN}, {TARGET_COLUMN},
                {', '.join(COVARIATE_COLUMNS)}
            FROM `{PROJECT_ID}.{BQ_DATASET}.{BQ_TABLE}`
        )
    )
    WHERE {SERIES_COLUMN} = '{chosen_id}'
    ORDER BY {TIME_COLUMN}
"""
print(query)
explain = bq.query(query).to_dataframe()
explain.tail()
# Out:
#     SELECT *,
#         EXTRACT(DATE FROM time_series_timestamp) AS monday_of_week
#     FROM ML.EXPLAIN_FORECAST(
#         MODEL `luciexu.citibike.citibike-arima-fold-3-2025-11-04-09-44-52`,
#         STRUCT(10 AS horizon, 0.95 AS confidence_level),
#         (
#             SELECT time_serie_id, monday_of_week, qty,
#                 start_station_id, start_station_latitude, start_station_longitude, end_station_id, end_station_latitude, end_station_longitude, percentage_rain
#             FROM `luciexu.citibike.citibike_trips_prepped-fold-3-2025-11-04-09-44-52`
#         )
#     )
#     WHERE time_serie_id = '1avee30st_stmarkspl1ave'
#     ORDER BY monday_of_week
#                time_serie_id     time_series_timestamp time_series_type  \
# 162  1avee30st_stmarkspl1ave 2016-08-08 00:00:00+00:00         forecast
# 163  1avee30st_stmarkspl1ave 2016-08-15 00:00:00+00:00         forecast
# 164  1avee30st_stmarkspl1ave 2016-08-22 00:00:00+00:00         forecast
# 165  1avee30st_stmarkspl1ave 2016-08-29 00:00:00+00:00         forecast
# 166  1avee30st_stmarkspl1ave 2016-09-05 00:00:00+00:00         forecast
#
#      time_series_data  time_series_adjusted_data  standard_error  \
# 162          2.056178                   2.056178        0.910136
# 163          1.964000                   1.964000        0.910136
# 164          2.275166                   2.275166        0.910136
# 165          2.275188                   2.275188        0.910136
# 166          2.336180                   2.336180        0.910136
#
#      confidence_level  prediction_interval_lower_bound  \
# 162              0.95                         0.275536
# 163              0.95                         0.183357
# 164              0.95                         0.494523
# 165              0.95                         0.494545
# 166              0.95                         0.555537
#
#      prediction_interval_upper_bound     trend  ...  \
# 162                         3.836821 -0.170239  ...
# 163                         3.744642 -0.169912  ...
# 164                         4.055808 -0.169827  ...
# 165                         4.055830 -0.169806  ...
# 166                         4.116822 -0.169800  ...
#
#      holiday_effect_US_ElectionDay  attribution_start_station_id  \
# 162                            0.0                      1.151944
# 163                            0.0                      1.151944
# 164                            0.0                      1.361039
# 165                            0.0                      1.361039
# 166                            0.0                      1.151944
#
#      attribution_start_station_latitude  attribution_start_station_longitude  \
# 162                            0.191326                         1.851710e-10
# 163                            0.191326                         1.851710e-10
# 164                            0.191287                         1.852033e-10
# 165                            0.191287                         1.852033e-10
# 166                            0.191326                         1.851710e-10
#
#      attribution_end_station_id  attribution_end_station_latitude  \
# 162                   -0.312399                         -0.296148
# 163                   -0.312399                         -0.296148
# 164                   -0.449381                         -0.296179
# 165                   -0.449381                         -0.296179
# 166                   -0.312399                         -0.296148
#
#      attribution_end_station_longitude  attribution_percentage_rain  \
# 162                           0.232774                     0.355493
# 163                           0.232774                     0.262987
# 164                           0.232779                     0.502022
# 165                           0.232779                     0.502022
# 166                           0.232774                     0.635056
#
#      attribution___INTERCEPT__  monday_of_week
# 162                   0.903427      2016-08-08
# 163                   0.903427      2016-08-15
# 164                   0.903427      2016-08-22
# 165                   0.903427      2016-08-29
# 166                   0.903427      2016-09-05
#
# [5 rows x 74 columns]
